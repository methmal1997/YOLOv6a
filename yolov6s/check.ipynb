# %%
import torch as t
print(t.__version__)
# Out:
# 1.12.0

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.7

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.13.0

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/inference/exp/1.jpg', width=1000)

# %%
# !python tools/train.py --batch 16 --conf configs/yolov6n_finetune.py --data-path data/data.yaml --device 0 --epochs 10 --eval-interval 2
# Out:
# Using 1 GPU for training...
# training args are: Namespace(data_path='data/data.yaml', conf_file='configs/yolov6n_finetune.py', img_size=640, batch_size=16, epochs=10, workers=8, device='0', eval_interval=2, eval_final_only=False, heavy_eval_range=50, check_images=False, check_labels=False, output_dir='./runs/train', name='exp', dist_url='env://', gpu_count=0, local_rank=-1, resume=False, write_trainbatch_tb=False, rank=-1, world_size=1, save_dir='runs/train/exp14')
#
# Train: Final numbers of valid images: 1750/ labels: 1750.
# 0.0s for dataset initialization.
# Convert to COCO format
# 100%|█████████████████████████████████████| 182/182 [00:00<00:00, 284518.57it/s]
# Convert to COCO format finished. Resutls saved in ./custom_dataset/annotations/instances_.json
# Val: Final numbers of valid images: 182/ labels: 182.
# 0.0s for dataset initialization.
# Loading state_dict from ./weights/yolov6n.pt for fine-tuning...
# Model: Model(
#   (backbone): EfficientRep(
# ...

# %%
#cd YOLOv6
# !python tools/infer.py --weights runs/train/exp14/weights/last_ckpt.pt --source img2.jpeg --device 0
# Out:
# Namespace(weights='runs/train/exp14/weights/last_ckpt.pt', source='img2.jpeg', yaml='data/coco.yaml', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='0', save_txt=False, save_img=True, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from runs/train/exp14/weights/last_ckpt.pt
#
# Fusing model...
# /data/shared/methmal/anaconda3/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352660876/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 68.81it/s]
# ...

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/inference/img2.jpeg', width=1000)

# %%
#cd YOLOv6
# !python tools/infer.py --weights weights/yolov6s.pt --source img2.jpeg --device 0
# Out:
# Namespace(weights='weights/yolov6s.pt', source='img2.jpeg', yaml='data/coco.yaml', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='0', save_txt=False, save_img=True, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from weights/yolov6s.pt
#
# Fusing model...
# /data/shared/methmal/anaconda3/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352660876/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 65.53it/s]
# Results saved to runs/inference/exp

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/inference/img2.jpeg', width=1000)
